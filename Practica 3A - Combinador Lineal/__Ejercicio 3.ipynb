# %%
import numpy as np
from ClassNeuronaLineal import NeuronaLineal

Ptos = np.array([[1,1], [3,2], [5,5], [2,3], [4,3]])
X = Ptos[:,0].reshape(-1,1)
Y = Ptos[:,1]
alfa = 0.01
MAX_ITE = 100
Cota = 10e-06
nl = NeuronaLineal(alpha=0.01, n_iter=30, cotaE=10e-06, draw=1, title=['X','Y'])
nl.fit(X, Y)
#-- gráfico con la evolución del error ---
plt.plot(range(1, len(nl.errors_) + 1), nl.errors_, marker='o')
plt.xlabel('Iteraciones')
plt.ylabel('Cantidad de actualizaciones')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#      10 nl.fit(X, Y)
#      11 #-- gráfico con la evolución del error ---
# ---> 12 plt.plot(range(1, len(nl.errors_) + 1), nl.errors_, marker='o')
#      13 plt.xlabel('Iteraciones')
#      14 plt.ylabel('Cantidad de actualizaciones')
#
# NameError: name 'plt' is not defined
